# %%
from classification import *

import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img = cv2.imread('/opt/ml/project/final-project-level3-cv-12/dataset/Test/20220518_212613.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
bboxes=[(1050, 900, 300, 300), (1540, 950, 280, 250)]

# %%
f, ax = plt.subplots(figsize=(8, 8))

for bbox in bboxes:
    x, y, w, h = bbox
    img = cv2.rectangle(img, (x, y), (x + w, y + h), color = (255, 0, 0), thickness=20)

ax.imshow(img)
plt.show()

# %%
model = Classifier()
model.get_label(img, bboxes)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# ['농심_배홍동비빔면', '팔도_팔도비빔면']
